# %%
# !unrar x EALPYOLO_quant_avgversion.rar /content/
# Out:
# UNRAR 6.11 beta 1 freeware      Copyright (c) 1993-2022 Alexander Roshal
#
#
# Extracting from EALPYOLO_quant_avgversion.rar
#
# Creating    /content/quantized-yolov5                                 OK
#   OK
# Creating    /content/quantized-yolov5/.git                            OK
#   OK
#   OK
#   OK
# Creating    /content/quantized-yolov5/.git/hooks                      OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
# Creating    /content/quantized-yolov5/.git/info                       OK
#   OK
# Creating    /content/quantized-yolov5/.git/logs                       OK
#   OK
# Creating    /content/quantized-yolov5/.git/logs/refs                  OK
# Creating    /content/quantized-yolov5/.git/logs/refs/heads            OK
#   OK
# Creating    /content/quantized-yolov5/.git/logs/refs/remotes          OK
# Creating    /content/quantized-yolov5/.git/logs/refs/remotes/origin   OK
#   OK
# ...

# %%
import kagglehub

# Download latest version

path = kagglehub.dataset_download("seyeon040768/car-detection-dataset")

print("Path to dataset files:", path)
# !ls /kaggle/input/car-detection-dataset/car_dataset-master/
# Out:
# Path to dataset files: /kaggle/input/car-detection-dataset
# README.md  test  train	valid

# %%
# !pip install torch torchvision numpy matplotlib
# !pip install brevitas
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.0/61.0 kB 3.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 802.0/802.0 kB 20.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 18.0/18.0 MB 85.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 894.6/894.6 kB 51.0 MB/s eta 0:00:00
# ...
#   Attempting uninstall: setuptools
#     Found existing installation: setuptools 75.2.0
#     Uninstalling setuptools-75.2.0:
#       Successfully uninstalled setuptools-75.2.0
#   Attempting uninstall: numpy
#     Found existing installation: numpy 2.0.2
#     Uninstalling numpy-2.0.2:
#       Successfully uninstalled numpy-2.0.2
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# ipython 7.34.0 requires jedi>=0.16, which is not installed.
# ...

# %%
# !python /content/quantized-yolov5/train.py --data /content/cars.yaml --cfg /content/quantized-yolov5/models/hub/yolov1-tiny-quant.yaml --weights '' --batch-size 128
# Out:
# ...
# No CUDA runtime is found, using CUDA_HOME='/usr/local/cuda'
# 2025-06-17 07:42:32.341552: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1750146152.721147    3393 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1750146152.823663    3393 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2025-06-17 07:42:33.599857: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# ...
